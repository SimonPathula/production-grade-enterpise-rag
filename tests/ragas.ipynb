# %%
import os
import asyncio
import pandas as pd
from dotenv import load_dotenv
from openai import AsyncOpenAI

import vertexai
from vertexai.language_models import TextEmbeddingModel
from ragas.llms import llm_factory
from ragas import SingleTurnSample
from ragas.metrics.collections import (
    Faithfulness,
    ContextPrecision,
    ContextRecall,
    AnswerCorrectness,
    AnswerRelevancy
)

from deepeval.test_case import LLMTestcase, ToolCall
from deepeval.metrics import ToolCorrectnessMetric
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 9
#       5 from openai import AsyncOpenAI
#       6
#       7 import vertexai
#       8 from vertexai.language_models import TextEmbeddingModel
# ----> 9 from ragas.llms import llm_factory
#      10 from ragas import SingleTurnSample
#      11 from ragas.metrics.collections import (
#      12     Faithfulness,
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\ragas\__init__.py:5
#       3 from ragas.dataset import Dataset, DataTable
#       4 from ragas.dataset_schema import EvaluationDataset, MultiTurnSample, SingleTurnSample
# ----> 5 from ragas.evaluation import aevaluate, evaluate
#       6 from ragas.experiment import Experiment, experiment, version_experiment
#       7 from ragas.run_config import RunConfig
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\ragas\evaluation.py:20
#      13 from ragas.callbacks import ChainType, RagasTracer, new_group
#      14 from ragas.dataset_schema import (
#      15     EvaluationDataset,
#      16     EvaluationResult,
#      17     MultiTurnSample,
#      18     SingleTurnSample,
#      19 )
# ---> 20 from ragas.embeddings.base import (
#      21     BaseRagasEmbedding,
#      22     BaseRagasEmbeddings,
#      23     LangchainEmbeddingsWrapper,
#      24     embedding_factory,
#      25 )
#      26 from ragas.exceptions import ExceptionInRunner
#      27 from ragas.executor import Executor
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\ragas\embeddings\__init__.py:3
#       1 # Legacy embeddings - maintain backward compatibility
#       2 # Modern embeddings - new interface
# ----> 3 from ragas.embeddings.base import (
#       4     BaseRagasEmbedding,
#       5     BaseRagasEmbeddings,
#       6     HuggingfaceEmbeddings,
#       7     LangchainEmbeddingsWrapper as _LangchainEmbeddingsWrapper,
#       8     LlamaIndexEmbeddingsWrapper as _LlamaIndexEmbeddingsWrapper,
#       9     embedding_factory as _embedding_factory,
#      10 )
#      11 from ragas.embeddings.google_provider import GoogleEmbeddings
#      12 from ragas.embeddings.haystack_wrapper import HaystackEmbeddingsWrapper
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\ragas\embeddings\base.py:11
#       9 import numpy as np
#      10 from langchain_core.embeddings import Embeddings
# ---> 11 from langchain_openai.embeddings import OpenAIEmbeddings
#      12 from pydantic.dataclasses import dataclass
#      13 from pydantic_core import CoreSchema, core_schema
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\langchain_openai\__init__.py:4
#       1 """Module for OpenAI integrations."""
#       3 from langchain_openai._version import __version__
# ----> 4 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       5 from langchain_openai.chat_models._client_utils import StreamChunkTimeoutError
#       6 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\langchain_openai\chat_models\azure.py:20
#      17 from pydantic import BaseModel, Field, SecretStr, model_validator
#      18 from typing_extensions import Self
# ---> 20 from langchain_openai.chat_models.base import BaseChatOpenAI, _get_default_model_profile
#      22 if TYPE_CHECKING:
#      23     from langchain_core.language_models import ModelProfile
#
# File d:\projects\enterpriserag\enterprise-env\Lib\site-packages\langchain_openai\chat_models\base.py:54
#      49 import tiktoken
#      50 from langchain_core.callbacks import (
#      51     AsyncCallbackManagerForLLMRun,
#      52     CallbackManagerForLLMRun,
#      53 )
# ---> 54 from langchain_core.exceptions import ContextOverflowError
#      55 from langchain_core.language_models import (
#      56     LanguageModelInput,
#      57     ModelProfileRegistry,
#      58 )
#      59 from langchain_core.language_models.chat_models import (
#      60     BaseChatModel,
#      61     LangSmithParams,
#      62 )
#
# ImportError: cannot import name 'ContextOverflowError' from 'langchain_core.exceptions' (d:\projects\enterpriserag\enterprise-env\Lib\site-packages\langchain_core\exceptions.py)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sys
print(sys.executable)

import datasets
print(datasets.__version__)
# Out:
# d:\projects\enterpriserag\enterprise-env\Scripts\python.exe
# 5.0.0
